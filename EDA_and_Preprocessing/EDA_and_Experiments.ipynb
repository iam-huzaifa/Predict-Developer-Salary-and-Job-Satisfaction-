# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('../Dataset/survey_results_public.csv')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_21136\2458849932.py:1: DtypeWarning: Columns (56,74,92,97,98,105,109,110,132,162,165) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('../Dataset/survey_results_public.csv')

# %%
pd.set_option('Display.max_columns',None)

# %% [markdown]
# # Basic Info:

# %%
df.shape
# Out:
# (49191, 172)

# %%
df.sample()
# Out:
#        ResponseId                      MainBranch              Age  \
# 46860       46861  I am a developer by profession  25-34 years old
#
#                                                EdLevel  \
# 46860  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                               Employment     EmploymentAddl  \
# 46860  Independent contractor, freelancer, or self-em...  None of the above
#
#        WorkExp                                    LearnCodeChoose LearnCode  \
# 46860      7.0  No, I am not new to coding and did not learn n...       NaN
#
#                                              LearnCodeAI  \
# 46860  Yes, I learned how to use AI-enabled tools req...
#
#                                               AILearnHow  YearsCode  \
# 46860  AI CodeGen tools or AI-enabled apps;Other onli...       12.0
#
#                      DevType OrgSize ICorPM RemoteWork PurchaseInfluence  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49191 entries, 0 to 49190
# Columns: 172 entries, ResponseId to JobSat
# dtypes: float64(52), int64(1), object(119)
# memory usage: 64.6+ MB

# %%
df.describe()
# Out:
#          ResponseId       WorkExp     YearsCode  TechEndorse_1  TechEndorse_2  \
# count  49191.000000  42893.000000  43042.000000   35975.000000   35975.000000
# mean   24596.000000     13.367403     16.570861       7.867352       4.104211
# std    14200.362883     10.800117     11.787610       2.397432       2.275821
# min        1.000000      1.000000      1.000000       1.000000       1.000000
# 25%    12298.500000      5.000000      8.000000       7.000000       2.000000
# 50%    24596.000000     10.000000     14.000000       9.000000       4.000000
# 75%    36893.500000     20.000000     24.000000       9.000000       6.000000
# max    49191.000000    100.000000    100.000000      14.000000      14.000000
#
#        TechEndorse_3  TechEndorse_4  TechEndorse_5  TechEndorse_6  \
# count   35975.000000   35975.000000   35975.000000   35975.000000
# mean        4.110271       5.678193       4.119388       5.225990
# std         2.329536       2.398084       2.437945       2.801045
# ...

# %% [markdown]
# # Remove NaN:

# %%
df.isna().sum().sort_values(ascending=False).head(60).to_frame('missing_values')
# Out:
#                                     missing_values
# AIAgentObsWrite                              48927
# SOTagsWant Entry                             48761
# SOTagsHaveEntry                              48733
# AIModelsWantEntry                            48716
# AIAgentOrchWrite                             48713
# JobSatPoints_15_TEXT                         48527
# AIAgentKnowWrite                             48425
# AIModelsHaveEntry                            48415
# SO_Actions_15_TEXT                           48368
# AIAgentExtWrite                              48332
# CommPlatformWantEntr                         48007
# CommPlatformHaveEntr                         47715
# DatabaseWantEntry                            47658
# OfficeStackWantEntry                         47574
# TechOppose_15_TEXT                           47544
# TechEndorse_13_TEXT                          47182
# DevEnvWantEntry                              47079
# ...

# %%
plt.figure(figsize=(20,18))
sns.heatmap(df.isna())
# Out:
# <Axes: >

# %%
df.dropna(subset=['ConvertedCompYearly','JobSat'],inplace=True)

# %%
df.shape
# Out:
# (19449, 172)

# %%
df.drop(columns=df.columns[df.isna().mean()*100 > 55])
# Out:
#        ResponseId                      MainBranch              Age  \
# 0               1  I am a developer by profession  25-34 years old
# 1               2  I am a developer by profession  25-34 years old
# 2               3  I am a developer by profession  35-44 years old
# 3               4  I am a developer by profession  35-44 years old
# 4               5  I am a developer by profession  35-44 years old
# ...           ...                             ...              ...
# 49075       49076  I am a developer by profession  25-34 years old
# 49105       49106  I am a developer by profession  18-24 years old
# 49106       49107  I am a developer by profession  45-54 years old
# 49121       49122  I am a developer by profession  25-34 years old
# 49122       49123  I am a developer by profession  25-34 years old
#
#                                                  EdLevel  \
# 0        Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...

# %%
cols_to_drop = df.columns[df.isna().mean() * 100 > 55]
cols_to_drop.tolist()
# Out:
# ['TechEndorse_13_TEXT',
#  'TechOppose_15_TEXT',
#  'JobSatPoints_15_TEXT',
#  'LanguagesHaveEntry',
#  'LanguagesWantEntry',
#  'DatabaseHaveEntry',
#  'DatabaseWantEntry',
#  'PlatformHaveEntry',
#  'PlatformWantEntry',
#  'WebframeHaveEntry',
#  'WebframeWantEntry',
#  'DevEnvHaveEntry',
#  'DevEnvWantEntry',
#  'SOTagsWantToWorkWith',
#  'SOTagsAdmired',
#  'SOTagsHaveEntry',
#  'SOTagsWant Entry',
#  'OfficeStackHaveEntry',
#  'OfficeStackWantEntry',
#  'CommPlatformHaveEntr',
#  'CommPlatformWantEntr',
#  'AIModelsWantToWorkWith',
#  'AIModelsAdmired',
#  'AIModelsHaveEntry',
#  'AIModelsWantEntry',
#  'SO_Actions_15_TEXT',
#  'AIToolPlan to mostly use AI',
#  'AIToolCurrently mostly AI',
#  'AIAgent_Uses',
#  'AgentUsesGeneral',
#  'AIAgentImpactSomewhat agree',
#  'AIAgentImpactNeutral',
#  'AIAgentImpactSomewhat disagree',
#  'AIAgentImpactStrongly agree',
#  'AIAgentImpactStrongly disagree',
#  'AIAgentChallengesSomewhat disagree',
#  'AIAgentChallengesStrongly disagree',
# ...

# %% [markdown]
# # EDA

# %%
df['CompTotal']
# Out:
# 0          52800.0
# 1          90000.0
# 2        2214000.0
# 3          31200.0
# 4          60000.0
#            ...
# 49075      60500.0
# 49105      36000.0
# 49106    1224000.0
# 49121      50000.0
# 49122      40000.0
# Name: CompTotal, Length: 19449, dtype: float64

# %%
df['ConvertedCompYearly']
# Out:
# 0         61256.0
# 1        104413.0
# 2         53061.0
# 3         36197.0
# 4         60000.0
#            ...
# 49075     82366.0
# 49105       719.0
# 49106     69008.0
# 49121     58007.0
# 49122     46406.0
# Name: ConvertedCompYearly, Length: 19449, dtype: float64

# %%
df['Currency']
# Out:
# 0               EUR European Euro
# 1               EUR European Euro
# 2           UAH Ukrainian hryvnia
# 3               EUR European Euro
# 4        USD United States dollar
#                    ...
# 49075          GBP Pound sterling
# 49105         EGP\tEgyptian pound
# 49106     ZAR\tSouth African rand
# 49121           EUR European Euro
# 49122           EUR European Euro
# Name: Currency, Length: 19449, dtype: object

# %%
df['Country']
# Out:
# 0                                                  Ukraine
# 1                                              Netherlands
# 2                                                  Ukraine
# 3                                                  Ukraine
# 4                                                  Ukraine
#                                ...
# 49075    United Kingdom of Great Britain and Northern I...
# 49105                                                Egypt
# 49106                                         South Africa
# 49121                                               France
# 49122                                                Italy
# Name: Country, Length: 19449, dtype: object

# %%
df.head(1)
# Out:
#    ResponseId                      MainBranch              Age  \
# 0           1  I am a developer by profession  25-34 years old
#
#                                            EdLevel Employment  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)   Employed
#
#                                     EmploymentAddl  WorkExp  \
# 0  Caring for dependents (children, elderly, etc.)      8.0
#
#                                      LearnCodeChoose  \
# 0  Yes, I am not new to coding but am learning ne...
#
#                                            LearnCode  \
# 0  Online Courses or Certification (includes all ...
#
#                                          LearnCodeAI  \
# 0  Yes, I learned how to use AI-enabled tools for...
#
#                             AILearnHow  YearsCode            DevType  \
# 0  AI CodeGen tools or AI-enabled apps       14.0  Developer, mobile
#
#               OrgSize          ICorPM RemoteWork  \
# 0  20 to 99 employees  People manager     Remote
#
# ...

# %%
columns = [
    "MainBranch", "Age", "EdLevel", "Employment", "EmploymentAddl",
    "WorkExp", "LearnCodeChoose", "LearnCode", "LearnCodeAI", "AILearnHow",
    "YearsCode", "DevType", "OrgSize", "ICorPM", "RemoteWork",
    "PurchaseInfluence", "AIThreat", "NewRole", "ToolCountWork",
    "ToolCountPersonal", "Country", "LanguageChoice",
    "LanguageHaveWorkedWith", "DatabaseChoice",
    "DatabaseHaveWorkedWith", "PlatformChoice",
    "PlatformHaveWorkedWith", "WebframeHaveWorkedWith",
    "DevEnvsHaveWorkedWith", "OpSysProfessional use",
    "AIModelsChoice", "AIModelsHaveWorkedWith", "AISelect",
    "ConvertedCompYearly", "JobSat"
]

df2 = df[columns]

# %%
df2.shape
# Out:
# (19449, 35)

# %%
df2
# Out:
#                            MainBranch              Age  \
# 0      I am a developer by profession  25-34 years old
# 1      I am a developer by profession  25-34 years old
# 2      I am a developer by profession  35-44 years old
# 3      I am a developer by profession  35-44 years old
# 4      I am a developer by profession  35-44 years old
# ...                               ...              ...
# 49075  I am a developer by profession  25-34 years old
# 49105  I am a developer by profession  18-24 years old
# 49106  I am a developer by profession  45-54 years old
# 49121  I am a developer by profession  25-34 years old
# 49122  I am a developer by profession  25-34 years old
#
#                                                  EdLevel  \
# 0        Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1                    Associate degree (A.A., A.S., etc.)
# 2           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...

# %%
df2.isna().sum().sort_values()
# Out:
# MainBranch                   0
# Age                          0
# Employment                   0
# DevType                      0
# Country                      0
# ConvertedCompYearly          0
# JobSat                       0
# LearnCodeChoose              8
# EdLevel                     11
# LearnCodeAI                 19
# AIThreat                    31
# YearsCode                   58
# NewRole                     65
# WorkExp                    198
# PurchaseInfluence          451
# AISelect                   494
# EmploymentAddl            1063
# LanguageChoice            1078
# DatabaseChoice            1232
# LanguageHaveWorkedWith    1251
# PlatformChoice            1431
# AIModelsChoice            1940
# OrgSize                   2009
# RemoteWork                2085
# ICorPM                    2259
# OpSysProfessional use     2316
# ToolCountWork             2880
# DevEnvsHaveWorkedWith     3688
# DatabaseHaveWorkedWith    3911
# PlatformHaveWorkedWith    4363
# ...

# %%
df2['EmploymentAddl'].sample(7) # not required
# Out:
# 29030          Engaged in paid work (20-29 hours per week)
# 5478           Engaged in paid work (10-19 hours per week)
# 5136           Engaged in paid work (20-29 hours per week)
# 40364                                    None of the above
# 39710      Caring for dependents (children, elderly, etc.)
# 37542                                    None of the above
# 37641    Caring for dependents (children, elderly, etc....
# Name: EmploymentAddl, dtype: object

# %%
df2['EmploymentAddl'].value_counts().nunique()
# Out:
# 45

# %%
df2['LearnCodeChoose'].value_counts()
# Out:
# LearnCodeChoose
# Yes, I am not new to coding but am learning new coding techniques or programming language      13680
# No, I am not new to coding and did not learn new coding techniques or programming languages     5589
# Yes, I am new to coding or currently a student                                                   172
# Name: count, dtype: int64

# %%
df2['LearnCode'].sample(7)
# Out:
# 46051                                                  NaN
# 22434                                                  NaN
# 11994                                                  NaN
# 13455                                                  NaN
# 42083    Other online resources (e.g. standard search, ...
# 4188                                                   NaN
# 3248     Other online resources (e.g. standard search, ...
# Name: LearnCode, dtype: object

# %%
df2['LearnCode'].value_counts().nunique()
# Out:
# 85

# %%
df2['LearnCodeAI'].sample(5)
# Out:
# 13079    No, I didn't spend time learning in the past year
# 30443    Yes, I learned how to use AI-enabled tools req...
# 46968    Yes, I learned how to use AI-enabled tools for...
# 29202    No, I learned something that was not related t...
# 10065    No, I learned something that was not related t...
# Name: LearnCodeAI, dtype: object

# %%
df2['LearnCodeAI'].value_counts()
# Out:
# LearnCodeAI
# Yes, I learned how to use AI-enabled tools required for my job or to benefit my career                                7819
# Yes, I learned how to use AI-enabled tools for my personal curiosity and/or hobbies                                   5824
# No, I learned something that was not related to AI or AI enablement as required for my job or to benefit my career    2072
# No, I learned something that was not related to AI or AI enablement for my personal curiosity and/or hobbies          1931
# No, I didn't spend time learning in the past year                                                                     1784
# Name: count, dtype: int64

# %%
df2['AILearnHow'].sample(5)
# Out:
# 42722    Technical documentation (is generated for/by t...
# 9976     Videos (not associated with specific online co...
# 40662    Technical documentation (is generated for/by t...
# 40236    AI CodeGen tools or AI-enabled apps;Technical ...
# 18393    Videos (not associated with specific online co...
# Name: AILearnHow, dtype: object

# %%
df2['AILearnHow'].value_counts().nunique()
# Out:
# 89

# %%
df2['YearsCode'].sample(7)
# Out:
# 2824     28.0
# 5321      8.0
# 45860    10.0
# 3746     34.0
# 30550    45.0
# 28544    14.0
# 10752    20.0
# Name: YearsCode, dtype: float64

# %%
df2.drop(columns=['EmploymentAddl','LearnCode','AILearnHow'], inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_21136\1214805117.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(columns=['EmploymentAddl','LearnCode','AILearnHow'], inplace=True)

# %%
df2.shape
# Out:
# (19449, 32)

# %%
df2['DevType'].sample(5)
# Out:
# 37552               Developer, full-stack
# 2973     Architect, software or solutions
# 37706               Developer, full-stack
# 47043                 Developer, back-end
# 7711                Developer, full-stack
# Name: DevType, dtype: object

# %%
df2['DevType'].value_counts().nunique()
# Out:
# 30

# %%
df2['OrgSize'].sample(5)
# Out:
# 5722                              10,000 or more employees
# 16060                             1,000 to 4,999 employees
# 44148                                   20 to 99 employees
# 9492     Just me - I am a freelancer, sole proprietor, ...
# 5386                              10,000 or more employees
# Name: OrgSize, dtype: object

# %%
df2['OrgSize'].value_counts()
# Out:
# OrgSize
# 20 to 99 employees                                    3736
# 100 to 499 employees                                  3371
# Less than 20 employees                                2871
# 10,000 or more employees                              2515
# 1,000 to 4,999 employees                              2148
# 500 to 999 employees                                  1310
# 5,000 to 9,999 employees                               806
# Just me - I am a freelancer, sole proprietor, etc.     463
# I don’t know                                           220
# Name: count, dtype: int64

# %%
df2['ICorPM'].sample(5)
# Out:
# 31504    Individual contributor
# 4614     Individual contributor
# 13309    Individual contributor
# 45478    Individual contributor
# 706      Individual contributor
# Name: ICorPM, dtype: object

# %%
df2['ICorPM'].value_counts()
# Out:
# ICorPM
# Individual contributor    14986
# People manager             2204
# Name: count, dtype: int64

# %%
df2['RemoteWork'].sample(5)
# Out:
# 508      Hybrid (some remote, leans heavy to in-person)
# 39793                                            Remote
# 5482                                             Remote
# 28528                                            Remote
# 10882                                            Remote
# Name: RemoteWork, dtype: object

# %%
df2['RemoteWork'].value_counts()
# Out:
# RemoteWork
# Remote                                                                          6253
# Hybrid (some remote, leans heavy to in-person)                                  3384
# Hybrid (some in-person, leans heavy to flexibility)                             3174
# In-person                                                                       2324
# Your choice (very flexible, you can come in when you want or just as needed)    2229
# Name: count, dtype: int64

# %%
df2['PurchaseInfluence'].sample(5)
# Out:
# 3152     Yes, I influenced the purchase of a tool that ...
# 23183                                                   No
# 5128     Yes, I influenced the purchase of a substantia...
# 27247                                                   No
# 8717                                                   NaN
# Name: PurchaseInfluence, dtype: object

# %%
df2['PurchaseInfluence'].value_counts()
# Out:
# PurchaseInfluence
# No                                                                                                                                    9822
# Yes, I influenced the purchase of a substantial addition to the tech stack                                                            3703
# Yes, I endorsed a tool that was open-source and is currently used by more than just myself but no purchase was made                   3121
# Yes, I influenced the purchase of a tool that more than five colleagues use but it is not a substantial addition to the tech stack    1632
# Yes, I endorsed a tool that was ultimately not purchased or used at my organization                                                    720
# Name: count, dtype: int64

# %%
df2['AIThreat'].sample(5)
# Out:
# 35410    I'm not sure
# 35698    I'm not sure
# 47504              No
# 46441              No
# 6051               No
# Name: AIThreat, dtype: object

# %%
df2['AIThreat'].value_counts()
# Out:
# AIThreat
# No              12753
# I'm not sure     3954
# Yes              2711
# Name: count, dtype: int64

# %%
df2['NewRole'].sample(6)
# Out:
# 42053    I have neither consider or transitioned into a...
# 28379    I have strongly considered changing my career ...
# 4337     I have somewhat considered changing my career ...
# 40170    I have neither consider or transitioned into a...
# 14548    I have somewhat considered changing my career ...
# 21059    I have neither consider or transitioned into a...
# Name: NewRole, dtype: object

# %%
df2['NewRole'].value_counts()
# Out:
# NewRole
# I have neither consider or transitioned into a new career or industry          8871
# I have somewhat considered changing my career and/or the industry I work in    5986
# I have strongly considered changing my career and/or the industry I work in    2598
# I have transitioned into a new career and/or industry voluntarily              1586
# I have transitioned into a new career and/or industry involuntarily             343
# Name: count, dtype: int64

# %%
df2['ToolCountWork'].sample(3)
# Out:
# 15934     3.0
# 19319     NaN
# 2880     20.0
# Name: ToolCountWork, dtype: float64

# %%
df2['ToolCountWork'].value_counts().head(6)
# Out:
# ToolCountWork
# 5.0     2864
# 10.0    2652
# 3.0     1471
# 4.0     1414
# 6.0     1284
# 8.0     1027
# Name: count, dtype: int64

# %%
df2['ToolCountPersonal'].sample(5)
# Out:
# 6503     10.0
# 16438     3.0
# 40441     5.0
# 1318      4.0
# 13931     5.0
# Name: ToolCountPersonal, dtype: float64

# %%
df2['ToolCountPersonal'].value_counts().nunique()
# Out:
# 34

# %%
df2['Country'].sample(7)
# Out:
# 23620                                              Ukraine
# 19394                             United States of America
# 14903                                              Germany
# 22356                                   Russian Federation
# 40145                             United States of America
# 15409    United Kingdom of Great Britain and Northern I...
# 16149                                             Malaysia
# Name: Country, dtype: object

# %%
df2['Country'].value_counts().nunique()
# Out:
# 81

# %%
df2['LanguageChoice'].sample(6)
# Out:
# 18513    NaN
# 37481    Yes
# 46877    Yes
# 21731    Yes
# 20599     No
# 45228    Yes
# Name: LanguageChoice, dtype: object

# %%
df2['LanguageChoice'].value_counts()
# Out:
# LanguageChoice
# Yes    18169
# No       202
# Name: count, dtype: int64

# %%
df2.drop(columns=['LanguageChoice'],inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_21136\4090894841.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(columns=['LanguageChoice'],inplace=True)

# %%
df2.shape
# Out:
# (19449, 31)

# %%
df2['LanguageHaveWorkedWith'].sample(6)
# Out:
# 10790                   C++;Go;HTML/CSS;JavaScript;PHP;SQL
# 31787    Bash/Shell (all shells);C#;Dart;GDScript;Java;...
# 6408           C#;C++;HTML/CSS;Python;SQL;Swift;TypeScript
# 18711    C++;HTML/CSS;JavaScript;PHP;PowerShell;Python;...
# 9211                 Assembly;C;C#;C++;HTML/CSS;JavaScript
# 23506                                                  NaN
# Name: LanguageHaveWorkedWith, dtype: object

# %%
df2['LanguageHaveWorkedWith'].value_counts().nunique()
# Out:
# 67

# %%
df2.drop(columns=['LanguageHaveWorkedWith'],inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_21136\3946185605.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(columns=['LanguageHaveWorkedWith'],inplace=True)

# %%
df2.shape
# Out:
# (19449, 30)

# %%
df2['DatabaseChoice'].sample(6)
# Out:
# 28933    Yes
# 5832     Yes
# 4674     Yes
# 3976     Yes
# 29654    NaN
# 43968    NaN
# Name: DatabaseChoice, dtype: object

# %%
df2['DatabaseChoice'].value_counts()
# Out:
# DatabaseChoice
# Yes    15819
# No      2398
# Name: count, dtype: int64

# %%
df2.drop(columns=['DatabaseChoice'],inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_21136\951713966.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(columns=['DatabaseChoice'],inplace=True)

# %%
df2.shape
# Out:
# (19449, 29)

# %%
df2['DatabaseHaveWorkedWith'].sample(6)
# Out:
# 29820                                   MongoDB;PostgreSQL
# 27557    BigQuery;Databricks SQL;Dynamodb;Elasticsearch...
# 16169    Elasticsearch;Microsoft SQL Server;MySQL;Postg...
# 12095                                        DuckDB;SQLite
# 16470         MongoDB;MySQL;PostgreSQL;Redis;SQLite;Valkey
# 27202    MariaDB;Microsoft Access;Microsoft SQL Server;...
# Name: DatabaseHaveWorkedWith, dtype: object

# %%
df2['DatabaseHaveWorkedWith'].value_counts().head(10)
# Out:
# DatabaseHaveWorkedWith
# PostgreSQL                         786
# Microsoft SQL Server               752
# PostgreSQL;SQLite                  324
# MySQL                              283
# PostgreSQL;Redis                   263
# SQLite                             239
# Microsoft SQL Server;SQLite        188
# Microsoft SQL Server;PostgreSQL    182
# MongoDB                            162
# PostgreSQL;Redis;SQLite            148
# Name: count, dtype: int64

# %%
df2['DatabaseHaveWorkedWith'].value_counts().nunique()
# Out:
# 71

# %%
df2.drop(columns=['DatabaseHaveWorkedWith'],inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_21136\2682393396.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(columns=['DatabaseHaveWorkedWith'],inplace=True)

# %%
df2.shape
# Out:
# (19449, 28)

# %%
df2['PlatformChoice'].sample(3)
# Out:
# 2286     Yes
# 28326    Yes
# 21406    Yes
# Name: PlatformChoice, dtype: object

# %%
df2['PlatformChoice'].value_counts()
# Out:
# PlatformChoice
# Yes    15004
# No      3014
# Name: count, dtype: int64

# %%
df2.drop(columns=['PlatformChoice'],inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_21136\3512575104.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(columns=['PlatformChoice'],inplace=True)

# %%
df2.shape
# Out:
# (19449, 27)

# %%
df2['PlatformHaveWorkedWith'].sample(6)
# Out:
# 17204    Docker;Kubernetes;Microsoft Azure;MSBuild;npm;...
# 9700     Amazon Web Services (AWS);Ansible;Docker;Homeb...
# 2581                                                   NaN
# 27309    Ansible;Cloudflare;Docker;Kubernetes;New Relic...
# 13575                        Kubernetes;Maven (build tool)
# 40094                                         Google Cloud
# Name: PlatformHaveWorkedWith, dtype: object

# %%
df2['PlatformHaveWorkedWith'].value_counts().nunique()
# Out:
# 35

# %%
df2.drop(columns=['PlatformHaveWorkedWith'],inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_21136\1570262549.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(columns=['PlatformHaveWorkedWith'],inplace=True)

# %%
df2.shape
# Out:
# (19449, 26)

# %%
df2['WebframeHaveWorkedWith'].value_counts()
# Out:
# WebframeHaveWorkedWith
# React                                                                 301
# Spring Boot                                                           283
# Node.js;React                                                         214
# Next.js;Node.js;React                                                 163
# FastAPI                                                               151
#                                                                      ...
# Angular;AngularJS;Next.js;Node.js;Nuxt.js;React;Spring Boot;Vue.js      1
# Angular;ASP.NET;ASP.NET Core;Django;FastAPI;jQuery;Node.js;Vue.js       1
# Django;FastAPI;Next.js;React;Vue.js                                     1
# jQuery;Laravel;Next.js;Node.js;React                                    1
# AngularJS;FastAPI;Flask;jQuery;Vue.js;WordPress                         1
# Name: count, Length: 5197, dtype: int64

# %%
df2.drop(columns=['WebframeHaveWorkedWith'],inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_21136\1862964105.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(columns=['WebframeHaveWorkedWith'],inplace=True)

# %%
df2.shape
# Out:
# (19449, 25)

# %%
df2['DevEnvsHaveWorkedWith'].sample(5)
# Out:
# 32874               IntelliJ IDEA;Notepad++;WebStorm
# 4131      Notepad++;Visual Studio;Visual Studio Code
# 2132                                             NaN
# 13389                                            NaN
# 6583     IntelliJ IDEA;Neovim;Vim;Visual Studio Code
# Name: DevEnvsHaveWorkedWith, dtype: object

# %%
df['DevEnvsHaveWorkedWith'].value_counts()
# Out:
# DevEnvsHaveWorkedWith
# Visual Studio Code                                                                                                              1133
# Visual Studio;Visual Studio Code                                                                                                 590
# Notepad++;Visual Studio;Visual Studio Code                                                                                       582
# Cursor;Visual Studio Code                                                                                                        308
# IntelliJ IDEA;Visual Studio Code                                                                                                 253
#                                                                                                                                 ...
# Android Studio;Notepad++;PyCharm;Vim;Visual Studio;Visual Studio Code;Xcode                                                        1
# ...

# %%
df2.drop(columns=['DevEnvsHaveWorkedWith'],inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_21136\1915022422.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(columns=['DevEnvsHaveWorkedWith'],inplace=True)

# %%
df2.shape
# Out:
# (19449, 24)

# %%
df2['OpSysProfessional use'].sample(5)
# Out:
# 15532       Ubuntu;Red Hat
# 8890                 MacOS
# 48663                MacOS
# 33466    MacOS;Android;iOS
# 33073                  NaN
# Name: OpSysProfessional use, dtype: object

# %%
df2['OpSysProfessional use'].value_counts().nunique()
# Out:
# 82

# %%
df2.drop(columns=['OpSysProfessional use'],inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_21136\3729753912.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(columns=['OpSysProfessional use'],inplace=True)

# %%
df2.shape
# Out:
# (19449, 23)

# %%
df2.columns
# Out:
# Index(['MainBranch', 'Age', 'EdLevel', 'Employment', 'WorkExp',
#        'LearnCodeChoose', 'LearnCodeAI', 'YearsCode', 'DevType', 'OrgSize',
#        'ICorPM', 'RemoteWork', 'PurchaseInfluence', 'AIThreat', 'NewRole',
#        'ToolCountWork', 'ToolCountPersonal', 'Country', 'AIModelsChoice',
#        'AIModelsHaveWorkedWith', 'AISelect', 'ConvertedCompYearly', 'JobSat'],
#       dtype='object')

# %%
df2['AIModelsChoice'].sample(6)
# Out:
# 37451     No
# 40182     No
# 28591     No
# 2391     Yes
# 26103     No
# 13114     No
# Name: AIModelsChoice, dtype: object

# %%
df2['AIModelsChoice'].value_counts()
# Out:
# AIModelsChoice
# Yes    10402
# No      7107
# Name: count, dtype: int64

# %%
df2['AIModelsHaveWorkedWith'].sample(5)
# Out:
# 46516                                                  NaN
# 9778                                                   NaN
# 33961    Anthropic: Claude Sonnet;DeepSeek (R- Reasonin...
# 23842                                                  NaN
# 10265                                                  NaN
# Name: AIModelsHaveWorkedWith, dtype: object

# %%
df2['AIModelsHaveWorkedWith'].value_counts().nunique()
# Out:
# 64

# %%
df2.drop(columns=['AIModelsHaveWorkedWith'],inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_21136\244246489.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(columns=['AIModelsHaveWorkedWith'],inplace=True)

# %%
df2.shape
# Out:
# (19449, 22)

# %%
df2['AISelect'].sample(6)
# Out:
# 14085    Yes, I use AI tools monthly or infrequently
# 2571     Yes, I use AI tools monthly or infrequently
# 4254                       Yes, I use AI tools daily
# 39419                         No, but I plan to soon
# 2749     Yes, I use AI tools monthly or infrequently
# 18399                      Yes, I use AI tools daily
# Name: AISelect, dtype: object

# %%
df2['AISelect'].value_counts()
# Out:
# AISelect
# Yes, I use AI tools daily                      9725
# Yes, I use AI tools weekly                     3383
# No, and I don't plan to                        2648
# Yes, I use AI tools monthly or infrequently    2395
# No, but I plan to soon                          804
# Name: count, dtype: int64

# %%
df2.drop(columns=['AISelect'],inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_21136\228586966.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(columns=['AISelect'],inplace=True)

# %%
df2.shape
# Out:
# (19449, 21)

# %%
df2
# Out:
#                            MainBranch              Age  \
# 0      I am a developer by profession  25-34 years old
# 1      I am a developer by profession  25-34 years old
# 2      I am a developer by profession  35-44 years old
# 3      I am a developer by profession  35-44 years old
# 4      I am a developer by profession  35-44 years old
# ...                               ...              ...
# 49075  I am a developer by profession  25-34 years old
# 49105  I am a developer by profession  18-24 years old
# 49106  I am a developer by profession  45-54 years old
# 49121  I am a developer by profession  25-34 years old
# 49122  I am a developer by profession  25-34 years old
#
#                                                  EdLevel  \
# 0        Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1                    Associate degree (A.A., A.S., etc.)
# 2           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...

# %% [markdown]
# ## Save Cleaned Dataset

# %%
df2.to_csv('../Dataset/Cleaned_Dataset',index=False)

# %%
df2.sample()
# Out:
#                            MainBranch              Age  \
# 27427  I am a developer by profession  18-24 years old
#
#                                                  EdLevel Employment  WorkExp  \
# 27427  Some college/university study without earning ...   Employed      NaN
#
#                                          LearnCodeChoose  \
# 27427  Yes, I am not new to coding but am learning ne...
#
#                                              LearnCodeAI  YearsCode  DevType  \
# 27427  Yes, I learned how to use AI-enabled tools for...        5.0  Student
#
#                         OrgSize                  ICorPM RemoteWork  \
# 27427  1,000 to 4,999 employees  Individual contributor  In-person
#
#       PurchaseInfluence      AIThreat  \
# 27427                No  I'm not sure
#
#                                                  NewRole  ToolCountWork  \
# 27427  I have strongly considered changing my career ...            2.0
#
# ...

# %% [markdown]
# ## Properties:

# %%
# df2['MainBranch'],df2['Age'],df2['EdLevel'],df2['Employment'], df2['LearnCodeChoose'],df2['LearnCodeAI'], df2['DevType'],df2['OrgSize'],df2['ICorPM'],df2['RemoteWork'],df2['PurchaseInfluence'],df2['AIThreat'],df2['NewRole'],df2['Country'],df2['AIModelsChoice']->ohe
# Out:
# (19449, 172)

# %%
# df2['WorkExp'], df2['YearsCode'],df2['ToolCountWork'],df2['ToolCountPersonal'],df2['ConvertedCompYearly'],df2['JobSat']->skewed

# %% [markdown]
# ## Data Type:

# %%
df2.dtypes
# Out:
# MainBranch              object
# Age                     object
# EdLevel                 object
# Employment              object
# WorkExp                float64
# LearnCodeChoose         object
# LearnCodeAI             object
# YearsCode              float64
# DevType                 object
# OrgSize                 object
# ICorPM                  object
# RemoteWork              object
# PurchaseInfluence       object
# AIThreat                object
# NewRole                 object
# ToolCountWork          float64
# ToolCountPersonal      float64
# Country                 object
# AIModelsChoice          object
# ConvertedCompYearly    float64
# JobSat                 float64
# dtype: object

# %% [markdown]
# ### convert all object into categorical and all float column into int
